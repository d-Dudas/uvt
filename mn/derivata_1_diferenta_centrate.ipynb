# %%
import numpy
import matplotlib.pyplot as plt

def diferenta_centrata_doua_noduri(f, x, h):
    return (f(x + h) - f(x - h)) / (2 * h)

def diferenta_centrata_patru_noduri(f, x, h):
    return  (f(x - 2 * h) - 8 * f(x - h) + 8 * f(x + h) - f(x + 2 * h)) / (12 * h)

def diferenta_centrate(f, x, h, noduri = 2):
    if noduri == 2:
        return diferenta_centrata_doua_noduri(f, x, h)
    elif noduri == 4:
        return  diferenta_centrata_patru_noduri(f, x, h)
    else:
        return None

f = lambda x: x ** 3 - 27
x = 3
h = 0.1
print(diferenta_centrate(f, x, h, 4))

# Define the range of h values
d
# Out:
# 27.000000000000018

# %%
def derivata_de_grad_2_cu_diferenta_centrata_cu_5_noduri(f, x, h):
    return (-f(x + 2 * h) + 16*f(x + h) - 30*f(x) + 16*f(x - h) - f(x - 2 * h)) / (12 * h ** 2)

f = lambda x: x ** 3 - 27
x = 3
h = 0.1
print(derivata_de_grad_2_cu_diferenta_centrata_cu_5_noduri(f, x, h))
# Out:
# 18.000000000000412

# %%
def five_point_midpoint_formula(f, x, h):
    return (f(x - 2 * h) - 8 * f(x - h) + 8 * f(x + h) - f(x + 2 * h)) / (12 * h)

table_of_values = {
    2: 0.9798652,
    4: 0.9177710,
    6: 0.8080348,
    8: 0.6386093,
    10: 0.3843735
}

f = lambda x: table_of_values[x]
x = 6
h = 2
print(five_point_midpoint_formula(f, x, h))
# Out:
# -0.06824174583333333
